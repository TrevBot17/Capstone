# %%
#Reference: https://github.com/parshva45/Web-Crawler

import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import time
import os
from urllib3.exceptions import InsecureRequestWarning
from urllib3 import disable_warnings

# keyword_matches returns True if one of the following is True:
# - Anchor text starts with the keyword
# - Anchor text contains a space followed by the keyword followed by a space
# - Anchor text contains a space followed by the keyword
# - Anchor text ends with a space followed by the keyword
# - Text within the URL starts with the keyword
# - Text within the URL contains an underscore followed by the keyword followed by an underscore
# - Text within the URL contains an underscore followed by the keyword
# - Text within the URL ends with an underscore followed by the keyword

working_dir = 'C:/Users/JWeinstein/Capstone-main/src/'

def keyword_matches(keyword, url_text, href_url):
    return url_text.startswith(keyword) or url_text.endswith(' '+keyword) or ' '+keyword+' ' in url_text or ' '+keyword in url_text or href_url.startswith(keyword) or href_url.endswith('_'+keyword) or '_'+keyword+'_' in href_url or '_'+keyword in href_url


def spider(seed_url, keyword, crawl_depth):

    # Wiki Main Page, which needs to be excluded while crawling
    main_page = 'https://en.wikipedia.org/wiki/Main_Page'
    # Count of number of URLs crawled
    crawled_count = 0
    # Maximum depth of crawling reached
    max_depth = 1

    # Frontier - A list of URLS depicting a queue containing next URLs to be crawled
    #          - will contain the seed URL initially
    frontier_urls = [seed_url]
    # Seen - A list of URLs containing URLs crawled, empty initially
    seen_urls = []

    # creation of Logs directory, if not present
    newpath = working_dir + r'Logs' 
    if not os.path.exists(newpath):
        os.makedirs(newpath)

    # creation of Raw_TXT_Downloads directory, if not present (commented below)

    newpath = working_dir + r'Raw_TXT_Downloads'
    if not os.path.exists(newpath):
        os.makedirs(newpath)

    # Mentioning the seed URL and keyword in focused_crawler_log.txt
    focused_crawler_log = open(working_dir + "Logs/focused_crawler_log.txt","w")
    focused_crawler_log.write("Seed : "+seed_url+"\n")
    focused_crawler_log.write("Keyword : "+keyword+"\n\n")

    # Writing into log file starting with Depth 1
    focused_crawler_log.write("Depth 1 :\n\n")
    crawled_count+=1
    focused_crawler_log.write(str(crawled_count)+") "+seed_url+"\n\n")

    # flag is True iff the limit of 1000 URLS has not been reached
    flag = True
    print("\n----------------------------------------- At depth 1--------------------------------------------------------")
    print(str(crawled_count)+") "+seed_url)

    # download web page into a txt file
    name = seed_url[seed_url.rfind('/')+1:]
    # Specify url of the web page, here: seed_url 
    source = urlopen(seed_url).read()
    # Make a soup 
    soup = BeautifulSoup(source,'lxml')
    # Extract the plain text content from paragraphs
    text = ''
    for paragraph in soup.find_all('p'):
        text += paragraph.text
    # Clean text
    text = re.sub(r'\[.*?\]+', '', text)
    text = text.replace('\n', '')
    # get title of the wikipedia article
    page_title = soup.find_all('title')[0].text[:-12]
    file = open(working_dir + "Raw_TXT_Downloads/"+(str(crawled_count))+") "+name+".txt","w", encoding='utf-8')
    file.write(seed_url + '\n' + page_title + '\n' + text)
    file.close()

    # assuming maximum depth to crawl as Depth 3
    for depth in range (2, crawl_depth+1):
        if flag:
            print("\n----------------------------------------- At depth "+str(depth)+"--------------------------------------------------------")
            focused_crawler_log.write("Depth "+str(depth)+" :\n\n")
            extracted_urls = []

            # Traversing through all the URLs to be crawled as pointed by the Frontier
            for frontier_url in frontier_urls:

                # Enter only if limit of 1000 URLs not reached
                if flag:

                    # get the soup
                    disable_warnings(InsecureRequestWarning)
                    source_code = requests.get(frontier_url, verify = False)
                    plain_text = source_code.text
                    soup = BeautifulSoup(plain_text,"html.parser")

                    # Filter URLs, choose only the ones starting with '/wiki/'
                    for link in soup.find_all('a', href=re.compile('^/wiki/')):

                        # check if limit reached or not
                        if crawled_count < 1000 and flag:

                            # retrieve the Anchor text and Text of the URL
                            url_text = link.text
                            href_url = link.get('href')
                            truncated_href_url = href_url[6:]

                            # Call helper function to check if keyword matches or not
                            if keyword_matches(keyword, url_text, truncated_href_url):

                                # Ignore all the Administrative URLs
                                if ':' not in href_url:

                                    # Handle URLs with '#' seperately
                                    if '#' not in href_url:
                                        url = 'https://en.wikipedia.org'+href_url

                                        # URL should not be in either of Frontier, Extracted or Seen lists and should not be Wiki Main Page too
                                        if url not in frontier_urls and url not in extracted_urls and url not in seen_urls and url != main_page:
                                            
                                            # Respecting the Politeness Policy
                                            time.sleep(0.2)

                                            # download web page into a txt file
                                            name = url[url.rfind('/')+1:]                                            
                                            # Specify url of the web page, here: url 
                                            source = urlopen(url).read()
                                            # Make a soup 
                                            soup = BeautifulSoup(source,'lxml')
                                            # Extract the plain text content from paragraphs
                                            text = ''
                                            for paragraph in soup.find_all('p'):
                                                text += paragraph.text
                                            # Clean text
                                            text = re.sub(r'\[.*?\]+', '', text)
                                            text = text.replace('\n', '')
                                            # get title of the wikipedia article
                                            page_title = soup.find_all('title')[0].text[:-12]
                                            file = open(working_dir + "Raw_TXT_Downloads/"+(str(crawled_count+1))+") "+name+".txt","w", encoding='utf-8')
                                            file.write(url + '\n' + page_title + '\n' + text)
                                            file.close()
                                            
                                            extracted_urls.append(url)
                                            crawled_count+=1
                                            focused_crawler_log.write(str(crawled_count)+") "+url+"\n")
                                            print(str(crawled_count)+") "+url)

                                    else:
                                        # Handle URLs with '#'
                                        hash_pos = href_url.index('#')

                                        # Trim the URL from the start till index before '#'
                                        url = 'https://en.wikipedia.org'+href_url[:hash_pos]

                                        # URL should not be in either of Frontier, Extracted or Seen lists and should not be Wiki Main Page too
                                        if url not in frontier_urls and url not in extracted_urls and url not in seen_urls and url != main_page:
                                            
                                            # Respecting the Politeness Policy
                                            time.sleep(0.2)

                                            # download web page into a txt file
                                            name = url[url.rfind('/')+1:]                                            
                                            # Specify url of the web page, here: url 
                                            source = urlopen(url).read()
                                            # Make a soup 
                                            soup = BeautifulSoup(source,'lxml')
                                            # Extract the plain text content from paragraphs
                                            text = ''
                                            for paragraph in soup.find_all('p'):
                                                text += paragraph.text
                                            # Clean text
                                            text = re.sub(r'\[.*?\]+', '', text)
                                            text = text.replace('\n', '')
                                            # get title of the wikipedia article
                                            page_title = soup.find_all('title')[0].text[:-12]
                                            file = open(working_dir + "Raw_TXT_Downloads/"+(str(crawled_count+1))+") "+name+".txt","w", encoding='utf-8')
                                            file.write(url + '\n' + page_title + '\n' + text)
                                            file.close()

                                            extracted_urls.append(url)
                                            crawled_count+=1
                                            focused_crawler_log.write(str(crawled_count)+") "+url+"\n")
                                            print(str(crawled_count)+") "+url)

                        else:
                            # limit of 1000 URLs reached
                            flag = False
                            print("Limit of 1000 URLs reached")
                            max_depth = depth
                            break

                    # Copy all the URLs from Frontier to Seen
                    seen_urls.append(frontier_url)

            # Case when no URLs found on the depth
            if len(extracted_urls) == 0:
                print("No matching URLs at Depth "+str(depth)+"\n")
                focused_crawler_log.write("No matching URLs at Depth "+str(depth)+"\n\n")
                flag = False
                max_depth = depth
                break
            # Copy all the Extracted URLs to the Frontier
            frontier_urls = extracted_urls
            focused_crawler_log.write("\n")

    # Maximum depth of Depth 3 reached        
    if flag:
        print(f"Searched till max depth {crawl_depth}")
        max_depth = crawl_depth

    focused_crawler_log.write("------------------------------------------------------------------------------------\n")
    focused_crawler_log.write("Logistics :\n\n")
    focused_crawler_log.write("Number of matching searches : "+str(crawled_count)+"\n")
    focused_crawler_log.write("Maximum depth reached : Depth "+str(max_depth)+"\n")
    focused_crawler_log.close()

seed_url = 'https://en.wikipedia.org/wiki/Health'
crawl_depth = 10
keyword = 'health'
spider(seed_url, keyword, crawl_depth)
# Out:
# ----------------------------------------- At depth 1--------------------------------------------------------
# 1) https://en.wikipedia.org/wiki/Health
#
# ----------------------------------------- At depth 2--------------------------------------------------------
# 2) https://en.wikipedia.org/wiki/Mental_health
# 3) https://en.wikipedia.org/wiki/Health_care_provider
# 4) https://en.wikipedia.org/wiki/Healthy_community_design
# 5) https://en.wikipedia.org/wiki/Healthy_city
# 6) https://en.wikipedia.org/wiki/Healthy_environment
# 7) https://en.wikipedia.org/wiki/Health_care
# 8) https://en.wikipedia.org/wiki/Social_determinants_of_health
# 9) https://en.wikipedia.org/wiki/Health_science
# 10) https://en.wikipedia.org/wiki/Health_care_system
# 11) https://en.wikipedia.org/wiki/Health_policy
# 12) https://en.wikipedia.org/wiki/Global_health
# 13) https://en.wikipedia.org/wiki/Public_health
# 14) https://en.wikipedia.org/wiki/Health_education
# 15) https://en.wikipedia.org/wiki/School_health_services
# 16) https://en.wikipedia.org/wiki/Universal_health_care
# 17) https://en.wikipedia.org/wiki/Single-payer_health_care
# 18) https://en.wikipedia.org/wiki/Health_insurance
# 19) https://en.wikipedia.org/wiki/Electronic_health_record
# 20) https://en.wikipedia.org/wiki/Population_health
# 21) https://en.wikipedia.org/wiki/Health_services
# 22) https://en.wikipedia.org/wiki/Environmental_Health
# 23) https://en.wikipedia.org/wiki/Community_health
# 24) https://en.wikipedia.org/wiki/Behavioral_health
# 25) https://en.wikipedia.org/wiki/Occupational_health
# 26) https://en.wikipedia.org/wiki/Health_promotion
# 27) https://en.wikipedia.org/wiki/Health_system
# 28) https://en.wikipedia.org/wiki/Maternal_health
# 29) https://en.wikipedia.org/wiki/Occupational_safety_and_health
# 30) https://en.wikipedia.org/wiki/Environmental_health
# 31) https://en.wikipedia.org/wiki/Men%27s_health
# 32) https://en.wikipedia.org/wiki/Women%27s_health
# 33) https://en.wikipedia.org/wiki/Youth_health
# 34) https://en.wikipedia.org/wiki/List_of_health_and_wellness_podcasts
#
# ----------------------------------------- At depth 3--------------------------------------------------------
# 35) https://en.wikipedia.org/wiki/Outline_of_public_health
# 36) https://en.wikipedia.org/wiki/Dental_public_health
# 37) https://en.wikipedia.org/wiki/Sexual_and_reproductive_health
# 38) https://en.wikipedia.org/wiki/International_health
# 39) https://en.wikipedia.org/wiki/Behavior_change_(public_health)
# 40) https://en.wikipedia.org/wiki/List_of_national_public_health_agencies
# 41) https://en.wikipedia.org/wiki/Community_mental_health_service
# 42) https://en.wikipedia.org/wiki/Global_mental_health
# 43) https://en.wikipedia.org/wiki/Health_psychology
# 44) https://en.wikipedia.org/wiki/Infant_mental_health
# 45) https://en.wikipedia.org/wiki/Homelessness_and_mental_health
# 46) https://en.wikipedia.org/wiki/Mental_health_of_refugees
# 47) https://en.wikipedia.org/wiki/Deaf_mental_health_care
# 48) https://en.wikipedia.org/wiki/Mental_health_professional
# 49) https://en.wikipedia.org/wiki/Mental_health_in_aviation
# 50) https://en.wikipedia.org/wiki/Socioeconomic_status_and_mental_health
# 51) https://en.wikipedia.org/wiki/Mental_health_care_navigator
# 52) https://en.wikipedia.org/wiki/Mental_health_law
# 53) https://en.wikipedia.org/wiki/Mental_health_day
# 54) https://en.wikipedia.org/wiki/Mental_health_during_the_COVID-19_pandemic
# 55) https://en.wikipedia.org/wiki/Mental_health_first_aid
# 56) https://en.wikipedia.org/wiki/Self-help_groups_for_mental_health
# 57) https://en.wikipedia.org/wiki/Social_determinants_of_mental_health
# 58) https://en.wikipedia.org/wiki/Technology_and_mental_health_issues
# 59) https://en.wikipedia.org/wiki/Mental_health_of_Asian_Americans
# 60) https://en.wikipedia.org/wiki/Occupational_health_psychology
# 61) https://en.wikipedia.org/wiki/Cultural_competence_in_health_care
# 62) https://en.wikipedia.org/wiki/Public_health_genomics
# 63) https://en.wikipedia.org/wiki/Public_health_law
# 64) https://en.wikipedia.org/wiki/National_public_health_institutes
# 65) https://en.wikipedia.org/wiki/Public_health_intervention
# 66) https://en.wikipedia.org/wiki/Public_health_laboratory
# 67) https://en.wikipedia.org/wiki/Sociology_of_health_and_illness
# 68) https://en.wikipedia.org/wiki/Preventive_healthcare
# 69) https://en.wikipedia.org/wiki/Occupational_health_nursing
# 70) https://en.wikipedia.org/wiki/List_of_open-source_health_software
# 71) https://en.wikipedia.org/wiki/Public_health_informatics
# 72) https://en.wikipedia.org/wiki/Race_and_health
# 73) https://en.wikipedia.org/wiki/Public_health_surveillance
# 74) https://en.wikipedia.org/wiki/Professional_degrees_of_public_health
# 75) https://en.wikipedia.org/wiki/Health_professional
# 76) https://en.wikipedia.org/wiki/Health_facility
# 77) https://en.wikipedia.org/wiki/Allied_health_professional
# 78) https://en.wikipedia.org/wiki/Primary_health_care
# 79) https://en.wikipedia.org/wiki/Workplace_health_surveillance
# 80) https://en.wikipedia.org/wiki/List_of_occupational_safety_and_health_agencies
# 81) https://en.wikipedia.org/wiki/Environment,_health_and_safety
# 82) https://en.wikipedia.org/wiki/Right_to_a_healthy_environment
# 83) https://en.wikipedia.org/wiki/Allied_health_professions
# 84) https://en.wikipedia.org/wiki/Health_profession
# 85) https://en.wikipedia.org/wiki/Health_literacy
# 86) https://en.wikipedia.org/wiki/Health_facilities
# 87) https://en.wikipedia.org/wiki/Physical_health
# 88) https://en.wikipedia.org/wiki/Allied_health
# 89) https://en.wikipedia.org/wiki/Community_health_worker
# 90) https://en.wikipedia.org/wiki/Health_professionals
# 91) https://en.wikipedia.org/wiki/Health_Care_System
# 92) https://en.wikipedia.org/wiki/National_health_insurance
# 93) https://en.wikipedia.org/wiki/Health_plan
# 94) https://en.wikipedia.org/wiki/Healthcare_industry
# 95) https://en.wikipedia.org/wiki/Social_model_of_disability
# 96) https://en.wikipedia.org/wiki/Health_care_systems
# 97) https://en.wikipedia.org/wiki/Social_insurance
# 98) https://en.wikipedia.org/wiki/Health_care_industry
# 99) https://en.wikipedia.org/wiki/Health_administration
# 100) https://en.wikipedia.org/wiki/Health_department
# 101) https://en.wikipedia.org/wiki/Health_professional_requisites
# 102) https://en.wikipedia.org/wiki/Personal_health_record
# 103) https://en.wikipedia.org/wiki/Philosophy_of_healthcare
# 104) https://en.wikipedia.org/wiki/WHO%27s_ranking_of_health_care_systems
# 105) https://en.wikipedia.org/wiki/Academic_health_science_centre
# 106) https://en.wikipedia.org/wiki/Artificial_intelligence_in_healthcare
# 107) https://en.wikipedia.org/wiki/Right_to_health
# 108) https://en.wikipedia.org/wiki/Sexual_and_reproductive_health_and_rights
# 109) https://en.wikipedia.org/wiki/Women%27s_health_nurse_practitioner
# 110) https://en.wikipedia.org/wiki/Psychiatric-mental_health_nurse_practitioner
# 111) https://en.wikipedia.org/wiki/Home_health_nursing
# 112) https://en.wikipedia.org/wiki/Psychiatric_and_mental_health_nursing
# 113) https://en.wikipedia.org/wiki/Public_health_nursing
# 114) https://en.wikipedia.org/wiki/Travel_health_nursing
# 115) https://en.wikipedia.org/wiki/Prison_healthcare
# 116) https://en.wikipedia.org/wiki/Rural_health
# 117) https://en.wikipedia.org/wiki/Social_determinants_of_health_in_poverty
# 118) https://en.wikipedia.org/wiki/Community_health_centers_in_the_United_States
# 119) https://en.wikipedia.org/wiki/Health_disparities
# 120) https://en.wikipedia.org/wiki/Health_equity
# 121) https://en.wikipedia.org/wiki/Gender_disparities_in_health
# 122) https://en.wikipedia.org/wiki/Health_status_indicators
# 123) https://en.wikipedia.org/wiki/Health_Outcomes_Research
# 124) https://en.wikipedia.org/wiki/ICU_scoring_systems
# 125) https://en.wikipedia.org/wiki/Health_effect
# 126) https://en.wikipedia.org/wiki/Social_determinants_of_health_in_Mexico
# 127) https://en.wikipedia.org/wiki/Outline_of_health
# 128) https://en.wikipedia.org/wiki/Index_of_health_articles
# 129) https://en.wikipedia.org/wiki/List_of_health_sciences_topics
# 130) https://en.wikipedia.org/wiki/Outline_of_health_sciences
# 131) https://en.wikipedia.org/wiki/Primary_healthcare
# 132) https://en.wikipedia.org/wiki/Continuity_of_health_care
# 133) https://en.wikipedia.org/wiki/Single-payer_healthcare
# 134) https://en.wikipedia.org/wiki/Unnecessary_health_care
# 135) https://en.wikipedia.org/wiki/Healthcare
# 136) https://en.wikipedia.org/wiki/Health_data
# 137) https://en.wikipedia.org/wiki/Health_Human_Resources
# 138) https://en.wikipedia.org/wiki/List_of_countries_by_quality_of_health_care
# 139) https://en.wikipedia.org/wiki/List_of_countries_by_health_expenditure_covered_by_government
# 140) https://en.wikipedia.org/wiki/World_Health_Organization_ranking_of_health_systems
# 141) https://en.wikipedia.org/wiki/Euro_health_consumer_index
# 142) https://en.wikipedia.org/wiki/List_of_countries_by_total_health_expenditure_per_capita
# 143) https://en.wikipedia.org/wiki/Acronyms_in_healthcare
# 144) https://en.wikipedia.org/wiki/Catholic_Church_and_health_care
# 145) https://en.wikipedia.org/wiki/Comparison_of_the_health_care_systems_in_Canada_and_the_United_States
# 146) https://en.wikipedia.org/wiki/Consumer-driven_health_care
# 147) https://en.wikipedia.org/wiki/Publicly_funded_health_care
# 148) https://en.wikipedia.org/wiki/Timeline_of_global_health
# 149) https://en.wikipedia.org/wiki/Two-tier_health_care
# 150) https://en.wikipedia.org/wiki/HealthEquity
# 151) https://en.wikipedia.org/wiki/Health_care_reform
# 152) https://en.wikipedia.org/wiki/Health_services_research
# 153) https://en.wikipedia.org/wiki/Health_systems
# 154) https://en.wikipedia.org/wiki/Reproductive_health
# 155) https://en.wikipedia.org/wiki/Canada%27s_national_health_insurance_program
# 156) https://en.wikipedia.org/wiki/Health_maintenance_organization
# 157) https://en.wikipedia.org/wiki/Health_workforce
# 158) https://en.wikipedia.org/wiki/Child_survival
# 159) https://en.wikipedia.org/wiki/Planetary_health
# 160) https://en.wikipedia.org/wiki/Migrant_health
# 161) https://en.wikipedia.org/wiki/Child_health_and_nutrition_in_Africa
# 162) https://en.wikipedia.org/wiki/Health_economics
# 163) https://en.wikipedia.org/wiki/Health_politics
# 164) https://en.wikipedia.org/wiki/Oral_health
# 165) https://en.wikipedia.org/wiki/Health_indicators
# 166) https://en.wikipedia.org/wiki/Healthcare_workers
# 167) https://en.wikipedia.org/wiki/Environmental_health_officer
# 168) https://en.wikipedia.org/wiki/Public_health_inspector
# 169) https://en.wikipedia.org/wiki/Healthism
# 170) https://en.wikipedia.org/wiki/Healthy_diet
# 171) https://en.wikipedia.org/wiki/Healthy_eating
# 172) https://en.wikipedia.org/wiki/Public_health_policy
# 173) https://en.wikipedia.org/wiki/Risk
# 174) https://en.wikipedia.org/wiki/Public_health_in_Brazil
# 175) https://en.wikipedia.org/wiki/Public_health_in_China
# 176) https://en.wikipedia.org/wiki/Public_health_in_Cuba
# 177) https://en.wikipedia.org/wiki/Public_health_in_India
# 178) https://en.wikipedia.org/wiki/Public_health_in_Mexico
# 179) https://en.wikipedia.org/wiki/Public_health_in_the_United_States
# 180) https://en.wikipedia.org/wiki/Healthcare_in_Cuba
# 181) https://en.wikipedia.org/wiki/Health_care_in_France
# 182) https://en.wikipedia.org/wiki/Healthcare_in_Mexico
# 183) https://en.wikipedia.org/wiki/Effects_of_climate_change_on_human_health
# 184) https://en.wikipedia.org/wiki/Humidity
# 185) https://en.wikipedia.org/wiki/Emotional_health
# 186) https://en.wikipedia.org/wiki/Online_health_communities
# 187) https://en.wikipedia.org/wiki/In_absentia_health_care
# 188) https://en.wikipedia.org/wiki/Use_of_technology_in_treatment_of_mental_disorders
# 189) https://en.wikipedia.org/wiki/School_health_and_nutrition_services
# 190) https://en.wikipedia.org/wiki/List_of_countries_with_universal_health_care
# 191) https://en.wikipedia.org/wiki/Health_care_finance_in_the_United_States
# 192) https://en.wikipedia.org/wiki/List_of_countries_by_health_insurance_coverage
# 193) https://en.wikipedia.org/wiki/Two-tier_healthcare
# 194) https://en.wikipedia.org/wiki/Universal_healthcare
# 195) https://en.wikipedia.org/wiki/Comparison_of_the_healthcare_systems_in_Canada_and_the_United_States
# 196) https://en.wikipedia.org/wiki/Social_health_insurance
# 197) https://en.wikipedia.org/wiki/Publicly_funded_healthcare
# 198) https://en.wikipedia.org/wiki/World_Health_Organization_ranking_of_health_systems_in_2000
# 199) https://en.wikipedia.org/wiki/Health_insurance_in_the_United_States
# 200) https://en.wikipedia.org/wiki/Health_care_reform_in_the_United_States
# 201) https://en.wikipedia.org/wiki/Preventive_health_care
# 202) https://en.wikipedia.org/wiki/Health_care_in_the_United_States
# 203) https://en.wikipedia.org/wiki/Veterans_Health_Administration
# 204) https://en.wikipedia.org/wiki/Vermont_health_care_reform
# 205) https://en.wikipedia.org/wiki/Public_health_journal
# 206) https://en.wikipedia.org/wiki/Public_health_insurance_option
# 207) https://en.wikipedia.org/wiki/Health_risk
# 208) https://en.wikipedia.org/wiki/Long-term_care
# 209) https://en.wikipedia.org/wiki/Short-term_health_insurance
# 210) https://en.wikipedia.org/wiki/Health_advocacy
# 211) https://en.wikipedia.org/wiki/Health_savings_account
# 212) https://en.wikipedia.org/wiki/High-deductible_health_plan
# 213) https://en.wikipedia.org/wiki/International_healthcare_accreditation
# 214) https://en.wikipedia.org/wiki/Self-funded_health_care
# 215) https://en.wikipedia.org/wiki/Workplace_health_promotion
# 216) https://en.wikipedia.org/wiki/Electronic_health_records_in_the_United_States
# 217) https://en.wikipedia.org/wiki/Electronic_health_records_in_England
# 218) https://en.wikipedia.org/wiki/Solid_health
# 219) https://en.wikipedia.org/wiki/Health_information_technology
# 220) https://en.wikipedia.org/wiki/Consumer_health_informatics
# 221) https://en.wikipedia.org/wiki/List_of_medical_and_health_informatics_journals
# 222) https://en.wikipedia.org/wiki/Barcode_technology_in_healthcare
# 223) https://en.wikipedia.org/wiki/List_of_freeware_health_software
# 224) https://en.wikipedia.org/wiki/Population_health_policies_and_interventions
# 225) https://en.wikipedia.org/wiki/Socioeconomic_status_and_health
# 226) https://en.wikipedia.org/wiki/Medicine
# 227) https://en.wikipedia.org/wiki/Vocational_rehabilitation
# 228) https://en.wikipedia.org/wiki/Health_marketing
# 229) https://en.wikipedia.org/wiki/Tertiary_healthcare
# 230) https://en.wikipedia.org/wiki/Cultural_competence_in_healthcare
# 231) https://en.wikipedia.org/wiki/Community_health_agent
# 232) https://en.wikipedia.org/wiki/Community_health_center
# 233) https://en.wikipedia.org/wiki/Veterinary_medicine
# 234) https://en.wikipedia.org/wiki/Agricultural_safety_and_health
# 235) https://en.wikipedia.org/wiki/Timeline_of_major_U.S._environmental_and_occupational_health_regulation
# 236) https://en.wikipedia.org/wiki/Reproductive_and_sexual_health
# 237) https://en.wikipedia.org/wiki/Breast_health
# 238) https://en.wikipedia.org/wiki/Bone_health
# 239) https://en.wikipedia.org/wiki/Women%27s_health_in_China
# 240) https://en.wikipedia.org/wiki/Women%27s_health_in_Ethiopia
# 241) https://en.wikipedia.org/wiki/Women%27s_health_in_India
# 242) https://en.wikipedia.org/wiki/Maternal_health_in_Rwanda
# 243) https://en.wikipedia.org/wiki/Vulvovaginal_health
# 244) https://en.wikipedia.org/wiki/Sexual_health_clinic
# 245) https://en.wikipedia.org/wiki/Ecological_health
# 246) https://en.wikipedia.org/wiki/Ecosystem_health
# 247) https://en.wikipedia.org/wiki/Environmental_health_policy
# 248) https://en.wikipedia.org/wiki/List_of_environmental_journals
# 249) https://en.wikipedia.org/wiki/Social_determinant_of_health
# 250) https://en.wikipedia.org/wiki/Sexual_health
# 251) https://en.wikipedia.org/wiki/Human_female_genitalia
# 252) https://en.wikipedia.org/wiki/Breasts
# 253) https://en.wikipedia.org/wiki/Complications_of_pregnancy
# 254) https://en.wikipedia.org/wiki/Breastfeeding_and_mental_health
# 255) https://en.wikipedia.org/wiki/Women%27s_reproductive_health_in_Russia
# 256) https://en.wikipedia.org/wiki/Adolescent_health
#
# ----------------------------------------- At depth 4--------------------------------------------------------
# 257) https://en.wikipedia.org/wiki/Index_of_oral_health_and_dental_articles
# 258) https://en.wikipedia.org/wiki/Outline_of_dentistry_and_oral_health
# 259) https://en.wikipedia.org/wiki/Sexual_health_(disambiguation)
# 260) https://en.wikipedia.org/wiki/Reproductive_medicine
# 261) https://en.wikipedia.org/wiki/Health_belief_model
# 262) https://en.wikipedia.org/wiki/Health_action_process_approach
# 263) https://en.wikipedia.org/wiki/Mental_health_professionals
# 264) https://en.wikipedia.org/wiki/Mental_health_in_Southeast_Africa
# 265) https://en.wikipedia.org/wiki/Mental_health_in_Australia
# 266) https://en.wikipedia.org/wiki/Mental_health_and_socioeconomic_status
# 267) https://en.wikipedia.org/wiki/Mental_health_in_Canada
# 268) https://en.wikipedia.org/wiki/Mental_health_in_the_Middle_East
# 269) https://en.wikipedia.org/wiki/Mental_health_in_Israel
# 270) https://en.wikipedia.org/wiki/Mental_health_in_the_United_States
# 271) https://en.wikipedia.org/wiki/Mental_health_in_China
# 272) https://en.wikipedia.org/wiki/Impact_of_health_on_intelligence
# 273) https://en.wikipedia.org/wiki/Refugee_health_in_the_United_States
# 274) https://en.wikipedia.org/wiki/Refugee_health_care_in_Canada
# 275) https://en.wikipedia.org/wiki/Refugee_health
# 276) https://en.wikipedia.org/wiki/Mental_health_counseling
# 277) https://en.wikipedia.org/wiki/Mental_health_counselor
# 278) https://en.wikipedia.org/wiki/Clinical_psychology
# 279) https://en.wikipedia.org/wiki/Psychiatric_and_mental_health_nurse_practitioner
# 280) https://en.wikipedia.org/wiki/Global_Mental_Health
# 281) https://en.wikipedia.org/wiki/Mental_health_inequality
# 282) https://en.wikipedia.org/wiki/Mental_health_tribunal
# 283) https://en.wikipedia.org/wiki/Mental_disorder
# 284) https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_neurological,_psychological_and_other_mental_health_outcomes
# 285) https://en.wikipedia.org/wiki/Public_health_mitigation_of_COVID-19
# 286) https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_other_health_issues
# 287) https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_healthcare_workers
# 288) https://en.wikipedia.org/wiki/Mental_health_triage
# 289) https://en.wikipedia.org/wiki/Mental_health_consumer
# 290) https://en.wikipedia.org/wiki/Psychiatric_survivors_movement
# 291) https://en.wikipedia.org/wiki/Race_and_health_in_the_United_States
# 292) https://en.wikipedia.org/wiki/Mental_health_of_Filipino_Americans
# 293) https://en.wikipedia.org/wiki/Immigrant_paradox
# 294) https://en.wikipedia.org/wiki/Healthcare_professional
# 295) https://en.wikipedia.org/wiki/Health_disparity
# 296) https://en.wikipedia.org/wiki/People%27s_Republic_of_China
# 297) https://en.wikipedia.org/wiki/Health_assessment
# 298) https://en.wikipedia.org/wiki/Urban_green_space
# 299) https://en.wikipedia.org/wiki/Healthcare_in_Canada
# 300) https://en.wikipedia.org/wiki/List_of_open-source_health_hardware
# 301) https://en.wikipedia.org/wiki/Health_informatics
# 302) https://en.wikipedia.org/wiki/State_health_department
# 303) https://en.wikipedia.org/wiki/Health_information_system
# 304) https://en.wikipedia.org/wiki/Health_inequality
# 305) https://en.wikipedia.org/wiki/Psychological_impact_of_discrimination_on_health
# 306) https://en.wikipedia.org/wiki/Health_human_resources
# 307) https://en.wikipedia.org/wiki/Health_information_management
# 308) https://en.wikipedia.org/wiki/Health_professions
# 309) https://en.wikipedia.org/wiki/Oral_health_therapist
# 310) https://en.wikipedia.org/wiki/Foot_health_practitioner
# 311) https://en.wikipedia.org/wiki/Dentist
# 312) https://en.wikipedia.org/wiki/Oral_health_care
# 313) https://en.wikipedia.org/wiki/List_of_healthcare_occupations
# 314) https://en.wikipedia.org/wiki/Ambulatory_care
# 315) https://en.wikipedia.org/wiki/Allied_health_profession
# 316) https://en.wikipedia.org/wiki/Emergency_healthcare
# 317) https://en.wikipedia.org/wiki/The_human_right_to_a_clean,_healthy_and_sustainable_environment
# 318) https://en.wikipedia.org/wiki/Numeracy
# 319) https://en.wikipedia.org/wiki/Mental_health_literacy
# 320) https://en.wikipedia.org/wiki/Primary_care
# 321) https://en.wikipedia.org/wiki/Barangay_Health_Volunteers
# 322) https://en.wikipedia.org/wiki/Universal_health_coverage_by_country
# 323) https://en.wikipedia.org/wiki/Healthcare_provider
# 324) https://en.wikipedia.org/wiki/Health_care_costs
# 325) https://en.wikipedia.org/wiki/Consumer-driven_healthcare
# 326) https://en.wikipedia.org/wiki/List_of_health_departments_and_ministries
# 327) https://en.wikipedia.org/wiki/Waiting_in_healthcare
# 328) https://en.wikipedia.org/wiki/List_of_health_and_medical_strikes
# 329) https://en.wikipedia.org/wiki/Electronic_health_records
# 330) https://en.wikipedia.org/wiki/Personal_health_application
# 331) https://en.wikipedia.org/wiki/List_of_countries_by_quality_of_healthcare
# 332) https://en.wikipedia.org/wiki/Hospital_network
# 333) https://en.wikipedia.org/wiki/Healthcare_management
# 334) https://en.wikipedia.org/wiki/Speech_recognition_software_in_healthcare
# 335) https://en.wikipedia.org/wiki/Disability_and_women%27s_health
# 336) https://en.wikipedia.org/wiki/Mental_health_nurse
# 337) https://en.wikipedia.org/wiki/Psychiatric_and_mental_health_nursing_in_the_United_States_Army
# 338) https://en.wikipedia.org/wiki/Psychiatric_and_mental_health_Nurse_Practitioner
# 339) https://en.wikipedia.org/wiki/Mental_health_nursing
# 340) https://en.wikipedia.org/wiki/College_health
# 341) https://en.wikipedia.org/wiki/Health_care_services
# 342) https://en.wikipedia.org/wiki/Mental_illness_in_American_prisons
# 343) https://en.wikipedia.org/wiki/Public_health_system
# 344) https://en.wikipedia.org/wiki/Causes_of_mental_disorders
# 345) https://en.wikipedia.org/wiki/Health_center
# 346) https://en.wikipedia.org/wiki/Massachusetts_health_care_reform
# 347) https://en.wikipedia.org/wiki/Indigenous_health_in_Australia
# 348) https://en.wikipedia.org/wiki/Economic_inequality
# 349) https://en.wikipedia.org/wiki/Climate_change_and_health
# 350) https://en.wikipedia.org/wiki/Health_workers
# 351) https://en.wikipedia.org/wiki/Health_sciences
# 352) https://en.wikipedia.org/wiki/Advance_health_care_directive
# 353) https://en.wikipedia.org/wiki/Determinants_of_health
# 354) https://en.wikipedia.org/wiki/Ethnicity_and_health
# 355) https://en.wikipedia.org/wiki/Holistic_health
# 356) https://en.wikipedia.org/wiki/Noise_health_effects
# 357) https://en.wikipedia.org/wiki/Posture_and_occupational_health
# 358) https://en.wikipedia.org/wiki/Rural_health_clinic
# 359) https://en.wikipedia.org/wiki/Lists_of_health_topics
# 360) https://en.wikipedia.org/wiki/Topic_outline_of_health
# 361) https://en.wikipedia.org/wiki/Topic_outline_of_health_science
# 362) https://en.wikipedia.org/wiki/Health_care_prices
# 363) https://en.wikipedia.org/wiki/Health_care_prices_in_the_United_States
# 364) https://en.wikipedia.org/wiki/Health_care_in_Canada
# 365) https://en.wikipedia.org/wiki/Digital_health
# 366) https://en.wikipedia.org/wiki/Health_care_analytics
# 367) https://en.wikipedia.org/wiki/Protected_health_information
# 368) https://en.wikipedia.org/wiki/HRHIS
# 369) https://en.wikipedia.org/wiki/List_of_countries_by_health_care_quality
# 370) https://en.wikipedia.org/wiki/List_of_OECD_health_expenditure_by_country_by_type_of_financing
# 371) https://en.wikipedia.org/wiki/Healthcare_in_Europe
# 372) https://en.wikipedia.org/wiki/Healthcare_system
# 373) https://en.wikipedia.org/wiki/List_of_countries_by_total_health_expenditure_(PPP)_per_capita
# 374) https://en.wikipedia.org/wiki/Clinton_health_care_plan
# 375) https://en.wikipedia.org/wiki/Health_reimbursement_account
# 376) https://en.wikipedia.org/wiki/Health_technology_in_the_United_States
# 377) https://en.wikipedia.org/wiki/Consumers_for_health_care_choices
# 378) https://en.wikipedia.org/wiki/Public_opinion_on_health_care_reform_in_the_United_States
# 379) https://en.wikipedia.org/wiki/PATH_(global_health_organization)
# 380) https://en.wikipedia.org/wiki/Priority-setting_in_global_health
# 381) https://en.wikipedia.org/wiki/Healthcare_reform_in_the_United_States
# 382) https://en.wikipedia.org/wiki/Canadian_and_American_health_care_systems_compared
# 383) https://en.wikipedia.org/wiki/History_of_health_care_reform_in_the_United_States
# 384) https://en.wikipedia.org/wiki/Clinton_health_care_plan_of_1993
# 385) https://en.wikipedia.org/wiki/List_of_healthcare_reform_advocacy_groups_in_the_United_States
# 386) https://en.wikipedia.org/wiki/Free_market_healthcare
# 387) https://en.wikipedia.org/wiki/Publicly-funded_health_care
# 388) https://en.wikipedia.org/wiki/Rights
# 389) https://en.wikipedia.org/wiki/Health_economics_(Germany)
# 390) https://en.wikipedia.org/wiki/Community_health_service
# 391) https://en.wikipedia.org/wiki/World_Health_Report_2012
# 392) https://en.wikipedia.org/wiki/Routine_health_outcomes_measurement
# 393) https://en.wikipedia.org/wiki/List_of_international_healthcare_accreditation_organizations
# 394) https://en.wikipedia.org/wiki/Health_regions_of_Canada
# 395) https://en.wikipedia.org/wiki/Case_management_(USA_health_system)
# 396) https://en.wikipedia.org/wiki/Behaviour_change_(public_health)
# 397) https://en.wikipedia.org/wiki/Planetary_diet
# 398) https://en.wikipedia.org/wiki/Maternal_and_child_health_in_Tanzania
# 399) https://en.wikipedia.org/wiki/Grossman_model_of_health_demand
# 400) https://en.wikipedia.org/wiki/Health_care_policy
# 401) https://en.wikipedia.org/wiki/Health_problem
# 402) https://en.wikipedia.org/wiki/Environmental_impact_of_meat_production
# 403) https://en.wikipedia.org/wiki/Planetary_health_diet
# 404) https://en.wikipedia.org/wiki/Copper_in_health
# 405) https://en.wikipedia.org/wiki/Health_risk_assessment
# 406) https://en.wikipedia.org/wiki/Occupational_health_and_safety
# 407) https://en.wikipedia.org/wiki/Healthcare_in_China
# 408) https://en.wikipedia.org/wiki/Women%27s_healthcare_in_the_People%27s_Republic_of_China
# 409) https://en.wikipedia.org/wiki/Child_health
# 410) https://en.wikipedia.org/wiki/Health_tourists
# 411) https://en.wikipedia.org/wiki/Mental_health_in_India
# 412) https://en.wikipedia.org/wiki/Public_health_system_in_India
# 413) https://en.wikipedia.org/wiki/Health_expenditure
# 414) https://en.wikipedia.org/wiki/Couverture_maladie_universelle
# 415) https://en.wikipedia.org/wiki/The_World_Health_Organization%27s_ranking_of_health_systems
# 416) https://en.wikipedia.org/wiki/Effects_of_climate_change_on_mental_health
# 417) https://en.wikipedia.org/wiki/Effects_of_global_warming_on_human_health
# 418) https://en.wikipedia.org/wiki/Universal_health_coverage
# 419) https://en.wikipedia.org/wiki/Public_health_insurance
# 420) https://en.wikipedia.org/wiki/Ministry_of_Health_(Israel)
# 421) https://en.wikipedia.org/wiki/Two-tier_health_care_system
# 422) https://en.wikipedia.org/wiki/Health_care_in_Greece
# 423) https://en.wikipedia.org/wiki/Strategic_health_authority
# 424) https://en.wikipedia.org/wiki/District_health_board
# 425) https://en.wikipedia.org/wiki/Health_benefits_(insurance)
# 426) https://en.wikipedia.org/wiki/Healthcare_systems
# 427) https://en.wikipedia.org/wiki/Healthy_San_Francisco
# 428) https://en.wikipedia.org/wiki/Indian_health_service
# 429) https://en.wikipedia.org/wiki/Health_insurance_exchange
# 430) https://en.wikipedia.org/wiki/Individually_purchased_health_insurance_in_the_United_States
# 431) https://en.wikipedia.org/wiki/Health_insurance_marketplace
# 432) https://en.wikipedia.org/wiki/Consumer_driven_health_care
# 433) https://en.wikipedia.org/wiki/Short_term_health_insurance
# 434) https://en.wikipedia.org/wiki/Health_care_sharing_ministry
# 435) https://en.wikipedia.org/wiki/Healthcare_in_the_United_States
# 436) https://en.wikipedia.org/wiki/Health_care_compared
# 437) https://en.wikipedia.org/wiki/Health_maintenance_organizations
# 438) https://en.wikipedia.org/wiki/Preventative_health_care
# 439) https://en.wikipedia.org/wiki/Health_reimbursement_arrangement
# 440) https://en.wikipedia.org/wiki/Health_insurance_coverage_in_the_United_States
# 441) https://en.wikipedia.org/wiki/Pay_for_performance_(healthcare)
# 442) https://en.wikipedia.org/wiki/Health_insurance_mandate
# 443) https://en.wikipedia.org/wiki/Australia_health_care_system
# 444) https://en.wikipedia.org/wiki/Canadian_health_care
# 445) https://en.wikipedia.org/wiki/French_healthcare_system
# 446) https://en.wikipedia.org/wiki/German_health_care_system
# 447) https://en.wikipedia.org/wiki/Netherlands_health_care_system
# 448) https://en.wikipedia.org/wiki/Switzerland_healthcare
# 449) https://en.wikipedia.org/wiki/UK_health_care
# 450) https://en.wikipedia.org/wiki/Health_care_efficiency
# 451) https://en.wikipedia.org/wiki/Poverty_and_health_in_the_United_States
# 452) https://en.wikipedia.org/wiki/Provisions_of_the_Patient_Protection_and_Affordable_Care_Act
# 453) https://en.wikipedia.org/wiki/Immigrant_health_care_in_the_United_States
# 454) https://en.wikipedia.org/wiki/List_of_countries_by_health_care_expenditures
# 455) https://en.wikipedia.org/wiki/List_of_healthcare_accreditation_organizations_in_the_United_States
# 456) https://en.wikipedia.org/wiki/Visitor_health_insurance
# 457) https://en.wikipedia.org/wiki/Nationalized_health_care
# 458) https://en.wikipedia.org/wiki/TRICARE
# 459) https://en.wikipedia.org/wiki/Universal_healthcare_coverage
# 460) https://en.wikipedia.org/wiki/Private_health_insurance_in_the_United_States
# 461) https://en.wikipedia.org/wiki/Health_insurance_cooperative
# 462) https://en.wikipedia.org/wiki/Multi-payer_healthcare
# 463) https://en.wikipedia.org/wiki/Home_care
# 464) https://en.wikipedia.org/wiki/Home_health_care
# 465) https://en.wikipedia.org/wiki/Individual_mandate
# 466) https://en.wikipedia.org/wiki/Essential_health_benefits
# 467) https://en.wikipedia.org/wiki/List_of_open-source_healthcare_software
# 468) https://en.wikipedia.org/wiki/Health_technology
# 469) https://en.wikipedia.org/wiki/Health_information_exchange
# 470) https://en.wikipedia.org/wiki/List_of_open_source_healthcare_software
# 471) https://en.wikipedia.org/wiki/Health_outcomes_research
# 472) https://en.wikipedia.org/wiki/Health_determinant
# 473) https://en.wikipedia.org/wiki/Family_health
# 474) https://en.wikipedia.org/wiki/Family_medicine
# 475) https://en.wikipedia.org/wiki/Veterinary_public_health
# 476) https://en.wikipedia.org/wiki/Women%27s_health_in_Bangladesh
# 477) https://en.wikipedia.org/wiki/Women%27s_health_in_Egypt
# 478) https://en.wikipedia.org/wiki/Women%27s_health_in_Indonesia
# 479) https://en.wikipedia.org/wiki/Women%27s_health_in_Iran
# 480) https://en.wikipedia.org/wiki/Women%27s_health_in_Lebanon
# 481) https://en.wikipedia.org/wiki/Women%27s_health_in_Pakistan
# 482) https://en.wikipedia.org/wiki/Women%27s_health_in_Turkey
# 483) https://en.wikipedia.org/wiki/Maternal_health_in_Ethiopia
# 484) https://en.wikipedia.org/wiki/Healthcare_in_India
# 485) https://en.wikipedia.org/wiki/Healthcare_professionals
# 486) https://en.wikipedia.org/wiki/Mental_health_disorders
# 487) https://en.wikipedia.org/wiki/Human_health
# 488) https://en.wikipedia.org/wiki/Abortion_and_mental_health
#
# ----------------------------------------- At depth 5--------------------------------------------------------
# 489) https://en.wikipedia.org/wiki/List_of_oral_health_and_dental_topics
# 490) https://en.wikipedia.org/wiki/Health_behavior
# 491) https://en.wikipedia.org/wiki/Mental_health_care
# 492) https://en.wikipedia.org/wiki/Mental_health_in_Lebanon
# 493) https://en.wikipedia.org/wiki/Mental_health_in_Cambodia
# 494) https://en.wikipedia.org/wiki/Mental_health_in_Indonesia
# 495) https://en.wikipedia.org/wiki/Mental_health_in_South_Korea
# 496) https://en.wikipedia.org/wiki/Mental_health_in_Nepal
# 497) https://en.wikipedia.org/wiki/Mental_health_in_Pakistan
# 498) https://en.wikipedia.org/wiki/Mental_health_in_the_Philippines
# 499) https://en.wikipedia.org/wiki/Mental_health_in_Russia
# 500) https://en.wikipedia.org/wiki/Mental_health_in_Singapore
# 501) https://en.wikipedia.org/wiki/Mental_health_in_Tajikistan
# 502) https://en.wikipedia.org/wiki/Mental_health_in_Hong_Kong
# 503) https://en.wikipedia.org/wiki/Cognitive_epidemiology
# 504) https://en.wikipedia.org/wiki/U.S._healthcare_system
# 505) https://en.wikipedia.org/wiki/Digital_media_use_and_mental_health
# 506) https://en.wikipedia.org/wiki/Mental_disorders_and_gender
# 507) https://en.wikipedia.org/wiki/Mental_health_court
# 508) https://en.wikipedia.org/wiki/Community_mental_health_services
# 509) https://en.wikipedia.org/wiki/Long-term_effects_of_alcohol_consumption
# 510) https://en.wikipedia.org/wiki/Mental_health_provider
# 511) https://en.wikipedia.org/wiki/Mental_health_consumers
# 512) https://en.wikipedia.org/wiki/Aggression_in_healthcare
# 513) https://en.wikipedia.org/wiki/Dental_Health
# 514) https://en.wikipedia.org/wiki/Slave_health_on_plantations_in_the_United_States
# 515) https://en.wikipedia.org/wiki/Public_health_emergency_(United_States)
# 516) https://en.wikipedia.org/wiki/Inequalities_in_health_care
# 517) https://en.wikipedia.org/wiki/Health_costs
# 518) https://en.wikipedia.org/wiki/Obstacles_to_receiving_mental_health_services_among_African_American_youth
# 519) https://en.wikipedia.org/wiki/Race_and_maternal_health_in_the_United_States
# 520) https://en.wikipedia.org/wiki/Health_in_China
# 521) https://en.wikipedia.org/wiki/Health_history
# 522) https://en.wikipedia.org/wiki/Comparison_of_Canadian_and_American_health_care_systems
# 523) https://en.wikipedia.org/wiki/Health_informatics_tools
# 524) https://en.wikipedia.org/wiki/Local_health_departments_in_the_United_States
# 525) https://en.wikipedia.org/wiki/Secretary_of_health
# 526) https://en.wikipedia.org/wiki/Health_inspector
# 527) https://en.wikipedia.org/wiki/Health_care_professional
# 528) https://en.wikipedia.org/wiki/State_health_agency
# 529) https://en.wikipedia.org/wiki/Health_record
# 530) https://en.wikipedia.org/wiki/Psychiatric_hospital
# 531) https://en.wikipedia.org/wiki/Federal_Compulsory_Medical_Insurance_Fund_(Russia)
# 532) https://en.wikipedia.org/wiki/Barangay_health_volunteer
# 533) https://en.wikipedia.org/wiki/Physical_Health
# 534) https://en.wikipedia.org/wiki/Mental_health_in_education
# 535) https://en.wikipedia.org/wiki/Comorbidity
# 536) https://en.wikipedia.org/wiki/Mental_health_among_female_offenders_in_the_United_States
# 537) https://en.wikipedia.org/wiki/Mental_health_issues_in_American_women%27s_prisons
# 538) https://en.wikipedia.org/wiki/Alcohol_and_health
# 539) https://en.wikipedia.org/wiki/Dentistry
# 540) https://en.wikipedia.org/wiki/Health_care_proxy
# 541) https://en.wikipedia.org/wiki/Advance_healthcare_directive
# 542) https://en.wikipedia.org/wiki/Healthcare_delivery
# 543) https://en.wikipedia.org/wiki/Cardiovascular_health
# 544) https://en.wikipedia.org/wiki/Health_information_exchange_(HIE)
# 545) https://en.wikipedia.org/wiki/Health_care_quality
# 546) https://en.wikipedia.org/wiki/Health_effects_of_tobacco
# 547) https://en.wikipedia.org/wiki/Health_systems_strengthening
# 548) https://en.wikipedia.org/wiki/1993_Clinton_health_care_plan
# 549) https://en.wikipedia.org/wiki/Barack_Obama_speech_to_joint_session_of_Congress,_September_2009
# 550) https://en.wikipedia.org/wiki/Free-market_healthcare
# 551) https://en.wikipedia.org/wiki/Health_care_economics
# 552) https://en.wikipedia.org/wiki/Health_tourism
# 553) https://en.wikipedia.org/wiki/Health_for_all
# 554) https://en.wikipedia.org/wiki/Risk_factor
# 555) https://en.wikipedia.org/wiki/Behavioral_health_outcomes_management
# 556) https://en.wikipedia.org/wiki/Public_health_care
# 557) https://en.wikipedia.org/wiki/Case_management_(mental_health)
# 558) https://en.wikipedia.org/wiki/Case_management_(US_healthcare_system)
# 559) https://en.wikipedia.org/wiki/Meat
# 560) https://en.wikipedia.org/wiki/Health_risk_assessments
# 561) https://en.wikipedia.org/wiki/Healthcare_system_reform_in_China
# 562) https://en.wikipedia.org/wiki/High_Deductible_Health_Plan
# 563) https://en.wikipedia.org/wiki/Joint_Commission_on_Accreditation_of_Healthcare_Organizations
# 564) https://en.wikipedia.org/wiki/Healthcare_in_Finland
# 565) https://en.wikipedia.org/wiki/Immigration_health_surcharge
# 566) https://en.wikipedia.org/wiki/Regional_health_authority_(UK)
# 567) https://en.wikipedia.org/wiki/Mental_health_trust
# 568) https://en.wikipedia.org/wiki/Healthcare_in_New_Zealand
# 569) https://en.wikipedia.org/wiki/Primary_health_organisation
# 570) https://en.wikipedia.org/wiki/List_of_chairpersons_of_district_health_boards
# 571) https://en.wikipedia.org/wiki/Nikki_Turner_(public_health_advocate)
# 572) https://en.wikipedia.org/wiki/Native_American_health
# 573) https://en.wikipedia.org/wiki/California_health_plan_marketplace
# 574) https://en.wikipedia.org/wiki/Kentucky_health_plan_marketplace
# 575) https://en.wikipedia.org/wiki/Washington_health_plan_marketplace
# 576) https://en.wikipedia.org/wiki/Individually_purchased_health_insurance
# 577) https://en.wikipedia.org/wiki/Value_based_health_care
# 578) https://en.wikipedia.org/wiki/Universal_health_care_system
# 579) https://en.wikipedia.org/wiki/Ministry_of_Health,_Labour_and_Welfare_(Japan)
# 580) https://en.wikipedia.org/wiki/Private_health_insurance_rebate
# 581) https://en.wikipedia.org/wiki/Rural_health_care_in_Australia
# 582) https://en.wikipedia.org/wiki/Healthcare_in_England
# 583) https://en.wikipedia.org/wiki/Outcomes_research
# 584) https://en.wikipedia.org/wiki/Poverty_and_mental_health
# 585) https://en.wikipedia.org/wiki/Healthcare_availability_for_undocumented_immigrants_in_the_United_States
# 586) https://en.wikipedia.org/wiki/Mental_health_and_immigration_detention
# 587) https://en.wikipedia.org/wiki/Healthcare_reform
# 588) https://en.wikipedia.org/wiki/Healthcare_reform_debate_in_the_United_States
# 589) https://en.wikipedia.org/wiki/Health_care_in_Germany
# 590) https://en.wikipedia.org/wiki/Pre-existing_condition
# 591) https://en.wikipedia.org/wiki/Clinical_surveillance
# 592) https://en.wikipedia.org/wiki/Health_centre
# 593) https://en.wikipedia.org/wiki/Medical_tourism
# 594) https://en.wikipedia.org/wiki/Subsidised_healthcare
#
# ----------------------------------------- At depth 6--------------------------------------------------------
# 595) https://en.wikipedia.org/wiki/Healthcare_in_South_Korea
# 596) https://en.wikipedia.org/wiki/Health_care_in_the_Philippines
# 597) https://en.wikipedia.org/wiki/Mental_health_worker
# 598) https://en.wikipedia.org/wiki/Evolutionary_psychiatry
# 599) https://en.wikipedia.org/wiki/Workplace_safety_and_health
# 600) https://en.wikipedia.org/wiki/Health_and_safety
# 601) https://en.wikipedia.org/wiki/Workplace_safety_in_healthcare_settings
# 602) https://en.wikipedia.org/wiki/African_American_health
# 603) https://en.wikipedia.org/wiki/Public_health_emergency_(disambiguation)
# 604) https://en.wikipedia.org/wiki/Racial_disparities_in_health
# 605) https://en.wikipedia.org/wiki/Health_care_providers
# 606) https://en.wikipedia.org/wiki/Reproductive_health_care_for_incarcerated_women_in_the_United_States
# 607) https://en.wikipedia.org/wiki/Power_of_attorney
# 608) https://en.wikipedia.org/wiki/Iron_Triangle_of_Health_Care
# 609) https://en.wikipedia.org/wiki/Health_systems_by_country
# 610) https://en.wikipedia.org/wiki/Health_associations
# 611) https://en.wikipedia.org/wiki/Women_and_smoking
# 612) https://en.wikipedia.org/wiki/Regional_health_authority_(Norway)
# 613) https://en.wikipedia.org/wiki/Area_health_authority
# 614) https://en.wikipedia.org/wiki/List_of_NHS_regional_health_authorities_(before_1996)
# 615) https://en.wikipedia.org/wiki/Community_mental_health_team
# 616) https://en.wikipedia.org/wiki/Mental_health_in_New_Zealand
# 617) https://en.wikipedia.org/wiki/Inequality_in_disease
# 618) https://en.wikipedia.org/wiki/Healthcare.gov
# 619) https://en.wikipedia.org/wiki/Value-based_health_care
# 620) https://en.wikipedia.org/wiki/Health_care_in_Switzerland
#
# ----------------------------------------- At depth 7--------------------------------------------------------
# 621) https://en.wikipedia.org/wiki/LGBTQI_health_in_South_Korea
# 622) https://en.wikipedia.org/wiki/Mental_health_care_in_the_Philippines
# 623) https://en.wikipedia.org/wiki/Public_health_emergency
# 624) https://en.wikipedia.org/wiki/Health_in_Paraguay
# 625) https://en.wikipedia.org/wiki/Right_to_health_care
# 626) https://en.wikipedia.org/wiki/Healthcare_system_reform_in_the_People%27s_Republic_of_China
# 627) https://en.wikipedia.org/wiki/Dental_health
# 628) https://en.wikipedia.org/wiki/Health_Trust
# 629) https://en.wikipedia.org/wiki/District_health_authority
# 630) https://en.wikipedia.org/wiki/Health_authority
# 631) https://en.wikipedia.org/wiki/List_of_district_health_authorities_in_England_and_Wales
# 632) https://en.wikipedia.org/wiki/Rights_of_mental_health_patients_in_New_Zealand
# 633) https://en.wikipedia.org/wiki/Mental_health_in_the_United_Kingdom
#
# ----------------------------------------- At depth 8--------------------------------------------------------
# 634) https://en.wikipedia.org/wiki/LGBT_health_in_South_Korea
# 635) https://en.wikipedia.org/wiki/Family_health_services_authority
# 636) https://en.wikipedia.org/wiki/Mental_health_in_Finland
# 637) https://en.wikipedia.org/wiki/Mental_health_in_the_Republic_of_Ireland
# 638) https://en.wikipedia.org/wiki/Mental_health_in_Malta
# 639) https://en.wikipedia.org/wiki/Mental_health_in_Montenegro
# 640) https://en.wikipedia.org/wiki/Mental_health_in_Norway
# 641) https://en.wikipedia.org/wiki/Mental_health_in_Switzerland
# 642) https://en.wikipedia.org/wiki/Mental_health_in_Ukraine
#
# ----------------------------------------- At depth 9--------------------------------------------------------
# 643) https://en.wikipedia.org/wiki/Mental_health_in_Ireland
# 644) https://en.wikipedia.org/wiki/Alcohol_consumption_and_health
#
# ----------------------------------------- At depth 10--------------------------------------------------------
# No matching URLs at Depth 10
